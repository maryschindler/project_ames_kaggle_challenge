# %% [markdown]
# # Project 2 - Ames Housing Data and Kaggle Challenge
# ## Revisited

# %% [markdown]
# When reviewing the various projects I completed during my time with General Assembly I found that Project 2, based on an existing Kaggle challenge, offered to most room for improvement. My notebooks were a mess: there was no clear organization to the repository as a whole and each individual notebook represented the full 'Data Science Process' (Cleaning through Model Deployment), each for a different list of features.
#
# While the project was not particularly complicated, the way in which I originally approached the project was: I now had a chance to improve upon the work I had done in a more succinct, cleaner manner.

# %% [markdown]
# **Imports:**

# %%
import pandas as pd
pd.set_option("display.max_columns", None)

import numpy as np
np.random.seed(42)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = "darkgrid")

# %% [markdown]
# **Reading in Data**

# %%
#reading in training and testing data
ames_df = pd.read_csv('../datasets/train.csv')
ames_test_df = pd.read_csv('../datasets/test.csv')

# %%
ames_df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
# 2   NaN          NaN         0        1     2010       WD      109000
# 3   NaN          NaN         0        4     2010       WD      174000
# 4   NaN          NaN         0        3     2010       WD      138500

# %%
print(f'The ames_df dataframe is {ames_df.shape} rows by columns')
# Out:
# The ames_df dataframe is (2051, 81) rows by columns

# %%
ames_test_df.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm    2fmCon      2Story             6             8
# 1        Norm        Norm    Duplex      1Story             5             4
# 2        Norm        Norm      1Fam      2Story             7             5
# 3        Norm        Norm      1Fam      1Story             5             6
# 4        Norm        Norm      1Fam      1Story             6             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1910            1950      Gable   CompShg      AsbShng      AsbShng
# 1        1977            1977      Gable   CompShg      Plywood      Plywood
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1923            2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1963            1963      Gable   CompShg      Plywood      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0         None           0.0         TA         Fa      Stone        Fa
# 1         None           0.0         TA         TA     CBlock        Gd
# 2         None           0.0         Gd         TA      PConc        Gd
# 3         None           0.0         Gd         TA     CBlock        TA
# 4      BrkFace         247.0         TA         TA     CBlock        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            Unf             0            Unf
# 1        TA            No            Unf             0            Unf
# 2        Gd            Av            GLQ           554            Unf
# 3        TA            No            Unf             0            Unf
# 4        TA            No            BLQ           609            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0             0         1020           1020    GasA         Gd           N
# 1             0         1967           1967    GasA         TA           Y
# 2             0          100            654    GasA         Ex           Y
# 3             0          968            968    GasA         TA           Y
# 4             0          785           1394    GasA         Gd           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      FuseP         908        1020                0         1928
# 1      SBrkr        1967           0                0         1967
# 2      SBrkr         664         832                0         1496
# 3      SBrkr         968           0                0          968
# 4      SBrkr        1394           0                0         1394
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0               0               0          2          0              4
# 1               0               0          2          0              6
# 2               1               0          2          1              3
# 3               0               0          1          0              2
# 4               1               0          1          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              2           Fa              9        Typ           0
# 1              2           TA             10        Typ           0
# 2              1           Gd              7        Typ           1
# 3              1           TA              5        Typ           0
# 4              1           TA              6        Typ           2
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Detchd         1910.0           Unf            1
# 1          NaN      Attchd         1977.0           Fin            2
# 2           Gd      Attchd         2006.0           RFn            2
# 3          NaN      Detchd         1935.0           Unf            2
# 4           Gd      Attchd         1963.0           RFn            2
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0          440          Po          Po           Y             0
# 1          580          TA          TA           Y           170
# 2          426          TA          TA           Y           100
# 3          480          Fa          TA           N             0
# 4          514          TA          TA           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             60             112           0             0          0     NaN
# 1              0               0           0             0          0     NaN
# 2             24               0           0             0          0     NaN
# 3              0             184           0             0          0     NaN
# 4             76               0           0           185          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type
# 0   NaN          NaN         0        4     2006       WD
# 1   NaN          NaN         0        8     2006       WD
# 2   NaN          NaN         0        9     2006       New
# 3   NaN          NaN         0        7     2007       WD
# 4   NaN          NaN         0        7     2009       WD

# %%
print(f'The ames_test_df dataframe is {ames_test_df.shape} rows by columns')
# Out:
# The ames_test_df dataframe is (878, 80) rows by columns

# %%
#renaming columns to preferred nomenclature 
ames_df.columns = ames_df.columns.str.strip().str.lower()
ames_df.columns = ames_df.columns.str.replace(' ', '_')
ames_df.columns[:5]
# Out:
# Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage'], dtype='object')

# %%
#doing the same thing to our testing data:
ames_test_df.columns = ames_test_df.columns.str.strip().str.lower()
ames_test_df.columns = ames_test_df.columns.str.replace(' ', '_')
ames_test_df.columns[:5]
# Out:
# Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage'], dtype='object')

# %%
#dropping 'id' and 'pid' columns:
ames_df.drop(columns = ['id', 'pid'], inplace = True)

#doing the same thing to our testing data:
ames_test_df.drop(columns = ['id', 'pid'], inplace = True)

# %% [markdown]
# **Exploring the Data**

# %%
ames_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ms_subclass      2051 non-null   int64
#  1   ms_zoning        2051 non-null   object
#  2   lot_frontage     1721 non-null   float64
#  3   lot_area         2051 non-null   int64
#  4   street           2051 non-null   object
#  5   alley            140 non-null    object
#  6   lot_shape        2051 non-null   object
#  7   land_contour     2051 non-null   object
#  8   utilities        2051 non-null   object
#  9   lot_config       2051 non-null   object
#  10  land_slope       2051 non-null   object
#  11  neighborhood     2051 non-null   object
#  12  condition_1      2051 non-null   object
#  13  condition_2      2051 non-null   object
#  14  bldg_type        2051 non-null   object
#  15  house_style      2051 non-null   object
#  16  overall_qual     2051 non-null   int64
#  17  overall_cond     2051 non-null   int64
#  18  year_built       2051 non-null   int64
#  19  year_remod/add   2051 non-null   int64
#  20  roof_style       2051 non-null   object
#  21  roof_matl        2051 non-null   object
#  22  exterior_1st     2051 non-null   object
#  23  exterior_2nd     2051 non-null   object
#  24  mas_vnr_type     2029 non-null   object
#  25  mas_vnr_area     2029 non-null   float64
#  26  exter_qual       2051 non-null   object
#  27  exter_cond       2051 non-null   object
#  28  foundation       2051 non-null   object
#  29  bsmt_qual        1996 non-null   object
#  30  bsmt_cond        1996 non-null   object
#  31  bsmt_exposure    1993 non-null   object
#  32  bsmtfin_type_1   1996 non-null   object
#  33  bsmtfin_sf_1     2050 non-null   float64
#  34  bsmtfin_type_2   1995 non-null   object
#  35  bsmtfin_sf_2     2050 non-null   float64
#  36  bsmt_unf_sf      2050 non-null   float64
#  37  total_bsmt_sf    2050 non-null   float64
#  38  heating          2051 non-null   object
#  39  heating_qc       2051 non-null   object
#  40  central_air      2051 non-null   object
#  41  electrical       2051 non-null   object
#  42  1st_flr_sf       2051 non-null   int64
#  43  2nd_flr_sf       2051 non-null   int64
#  44  low_qual_fin_sf  2051 non-null   int64
#  45  gr_liv_area      2051 non-null   int64
#  46  bsmt_full_bath   2049 non-null   float64
#  47  bsmt_half_bath   2049 non-null   float64
#  48  full_bath        2051 non-null   int64
#  49  half_bath        2051 non-null   int64
#  50  bedroom_abvgr    2051 non-null   int64
#  51  kitchen_abvgr    2051 non-null   int64
#  52  kitchen_qual     2051 non-null   object
#  53  totrms_abvgrd    2051 non-null   int64
#  54  functional       2051 non-null   object
#  55  fireplaces       2051 non-null   int64
#  56  fireplace_qu     1051 non-null   object
#  57  garage_type      1938 non-null   object
#  58  garage_yr_blt    1937 non-null   float64
#  59  garage_finish    1937 non-null   object
#  60  garage_cars      2050 non-null   float64
#  61  garage_area      2050 non-null   float64
#  62  garage_qual      1937 non-null   object
#  63  garage_cond      1937 non-null   object
#  64  paved_drive      2051 non-null   object
#  65  wood_deck_sf     2051 non-null   int64
#  66  open_porch_sf    2051 non-null   int64
#  67  enclosed_porch   2051 non-null   int64
#  68  3ssn_porch       2051 non-null   int64
#  69  screen_porch     2051 non-null   int64
#  70  pool_area        2051 non-null   int64
#  71  pool_qc          9 non-null      object
#  72  fence            400 non-null    object
#  73  misc_feature     65 non-null     object
#  74  misc_val         2051 non-null   int64
#  75  mo_sold          2051 non-null   int64
#  76  yr_sold          2051 non-null   int64
#  77  sale_type        2051 non-null   object
#  78  saleprice        2051 non-null   int64
# dtypes: float64(11), int64(26), object(42)
# memory usage: 1.2+ MB

# %%
np.round(ames_df.describe().T, 2)
# Out:
#                   count       mean       std      min       25%       50%  \
# ms_subclass      2051.0      57.01     42.82     20.0      20.0      50.0
# lot_frontage     1721.0      69.06     23.26     21.0      58.0      68.0
# lot_area         2051.0   10065.21   6742.49   1300.0    7500.0    9430.0
# overall_qual     2051.0       6.11      1.43      1.0       5.0       6.0
# overall_cond     2051.0       5.56      1.10      1.0       5.0       5.0
# year_built       2051.0    1971.71     30.18   1872.0    1953.5    1974.0
# year_remod/add   2051.0    1984.19     21.04   1950.0    1964.5    1993.0
# mas_vnr_area     2029.0      99.70    174.96      0.0       0.0       0.0
# bsmtfin_sf_1     2050.0     442.30    461.20      0.0       0.0     368.0
# bsmtfin_sf_2     2050.0      47.96    165.00      0.0       0.0       0.0
# bsmt_unf_sf      2050.0     567.73    444.95      0.0     220.0     474.5
# total_bsmt_sf    2050.0    1057.99    449.41      0.0     793.0     994.5
# 1st_flr_sf       2051.0    1164.49    396.45    334.0     879.5    1093.0
# 2nd_flr_sf       2051.0     329.33    425.67      0.0       0.0       0.0
# low_qual_fin_sf  2051.0       5.51     51.07      0.0       0.0       0.0
# gr_liv_area      2051.0    1499.33    500.45    334.0    1129.0    1444.0
# bsmt_full_bath   2049.0       0.43      0.52      0.0       0.0       0.0
# bsmt_half_bath   2049.0       0.06      0.25      0.0       0.0       0.0
# full_bath        2051.0       1.58      0.55      0.0       1.0       2.0
# half_bath        2051.0       0.37      0.50      0.0       0.0       0.0
# bedroom_abvgr    2051.0       2.84      0.83      0.0       2.0       3.0
# kitchen_abvgr    2051.0       1.04      0.21      0.0       1.0       1.0
# totrms_abvgrd    2051.0       6.44      1.56      2.0       5.0       6.0
# fireplaces       2051.0       0.59      0.64      0.0       0.0       1.0
# garage_yr_blt    1937.0    1978.71     25.44   1895.0    1961.0    1980.0
# garage_cars      2050.0       1.78      0.76      0.0       1.0       2.0
# garage_area      2050.0     473.67    215.93      0.0     319.0     480.0
# wood_deck_sf     2051.0      93.83    128.55      0.0       0.0       0.0
# open_porch_sf    2051.0      47.56     66.75      0.0       0.0      27.0
# enclosed_porch   2051.0      22.57     59.85      0.0       0.0       0.0
# 3ssn_porch       2051.0       2.59     25.23      0.0       0.0       0.0
# screen_porch     2051.0      16.51     57.37      0.0       0.0       0.0
# pool_area        2051.0       2.40     37.78      0.0       0.0       0.0
# misc_val         2051.0      51.57    573.39      0.0       0.0       0.0
# mo_sold          2051.0       6.22      2.74      1.0       4.0       6.0
# yr_sold          2051.0    2007.78      1.31   2006.0    2007.0    2008.0
# saleprice        2051.0  181469.70  79258.66  12789.0  129825.0  162500.0
#
#                        75%       max
# ms_subclass          70.00     190.0
# lot_frontage         80.00     313.0
# lot_area          11513.50  159000.0
# overall_qual          7.00      10.0
# overall_cond          6.00       9.0
# year_built         2001.00    2010.0
# year_remod/add     2004.00    2010.0
# mas_vnr_area        161.00    1600.0
# bsmtfin_sf_1        733.75    5644.0
# bsmtfin_sf_2          0.00    1474.0
# bsmt_unf_sf         811.00    2336.0
# total_bsmt_sf      1318.75    6110.0
# 1st_flr_sf         1405.00    5095.0
# 2nd_flr_sf          692.50    1862.0
# low_qual_fin_sf       0.00    1064.0
# gr_liv_area        1728.50    5642.0
# bsmt_full_bath        1.00       3.0
# bsmt_half_bath        0.00       2.0
# full_bath             2.00       4.0
# half_bath             1.00       2.0
# bedroom_abvgr         3.00       8.0
# kitchen_abvgr         1.00       3.0
# totrms_abvgrd         7.00      15.0
# fireplaces            1.00       4.0
# garage_yr_blt      2002.00    2207.0
# garage_cars           2.00       5.0
# garage_area         576.00    1418.0
# wood_deck_sf        168.00    1424.0
# open_porch_sf        70.00     547.0
# enclosed_porch        0.00     432.0
# 3ssn_porch            0.00     508.0
# screen_porch          0.00     490.0
# pool_area             0.00     800.0
# misc_val              0.00   17000.0
# mo_sold               8.00      12.0
# yr_sold            2009.00    2010.0
# saleprice        214000.00  611657.0

# %% [markdown]
# - Reviewing the above table, we see that there's an outlier/error for in the column 'garageyrblt', a value of 2207.0, apart from this, none of the other values standout.

# %%
ames_df.loc[ames_df['garage_yr_blt'] == 2207]
# Out:
#       ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# 1699           20        RL          68.0      8298   Pave   NaN       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1699          HLS    AllPub     Inside        Gtl       Timber        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1699        Norm      1Fam      1Story             8             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1699        2006            2007        Hip   CompShg      VinylSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1699      VinylSd          NaN           NaN         Gd         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1699        Gd        TA            Av            GLQ         583.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1699            Unf           0.0        963.0         1546.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1699         Ex           Y      SBrkr        1564           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1699                0         1564             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1699          0              2              1           Ex              6
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1699        Typ           1           Gd      Attchd         2207.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 1699           RFn          2.0        502.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 1699           Y           132              0               0           0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 1699             0          0     NaN   NaN          NaN         0        9
#
#       yr_sold sale_type  saleprice
# 1699     2007       New     267300

# %% [markdown]
# - The house was build in 2007 so I am going to replace the current 'Garage Yr Blt' value with 2007.

# %%
ames_df.loc[1699, ['garage_yr_blt']] = 2007

#https://stackoverflow.com/questions/23307301/replacing-column-values-in-a-pandas-dataframe
#df.loc[<row selection>, <column selection>]

# %% [markdown]
# **Checking Null Values**

# %%
#training data
np.round(ames_df.isna().sum().sort_values(ascending = False)[0:20] / len(ames_df), 4)
# Out:
# pool_qc           0.9956
# misc_feature      0.9683
# alley             0.9317
# fence             0.8050
# fireplace_qu      0.4876
# lot_frontage      0.1609
# garage_finish     0.0556
# garage_qual       0.0556
# garage_yr_blt     0.0556
# garage_cond       0.0556
# garage_type       0.0551
# bsmt_exposure     0.0283
# bsmtfin_type_2    0.0273
# bsmt_cond         0.0268
# bsmt_qual         0.0268
# bsmtfin_type_1    0.0268
# mas_vnr_area      0.0107
# mas_vnr_type      0.0107
# bsmt_full_bath    0.0010
# bsmt_half_bath    0.0010
# dtype: float64

# %%
#testing data
np.round(ames_test_df.isna().sum().sort_values(ascending = False)[0:20] / len(ames_df), 4)
# Out:
# pool_qc           0.4261
# misc_feature      0.4081
# alley             0.3998
# fence             0.3442
# fireplace_qu      0.2058
# lot_frontage      0.0780
# garage_yr_blt     0.0219
# garage_finish     0.0219
# garage_qual       0.0219
# garage_cond       0.0219
# garage_type       0.0215
# bsmtfin_type_2    0.0122
# bsmt_cond         0.0122
# bsmt_exposure     0.0122
# bsmtfin_type_1    0.0122
# bsmt_qual         0.0122
# electrical        0.0005
# mas_vnr_type      0.0005
# mas_vnr_area      0.0005
# totrms_abvgrd     0.0000
# dtype: float64

# %% [markdown]
# - In both the training and testing datasets the features 'pool_qc', 'misc_feature', 'alley', 'fence', and 'fireplace_qu' are missing more than 20% of their values. I will drop these features from modeling, a decision which is further supported by the fact that the aforementioned features, qualities of a home such as a pool, a fireplace, or misc. feature (like an elevator or tennis court) could account for outliers in Sale Price.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# **Basic Visualizations**
#
# This section contains basic data visualizations representing the frequencies of measurements from the dataframe.

# %%
object_cols = ames_df.select_dtypes('object').columns
object_cols
# Out:
# Index(['ms_zoning', 'street', 'alley', 'lot_shape', 'land_contour',
#        'utilities', 'lot_config', 'land_slope', 'neighborhood', 'condition_1',
#        'condition_2', 'bldg_type', 'house_style', 'roof_style', 'roof_matl',
#        'exterior_1st', 'exterior_2nd', 'mas_vnr_type', 'exter_qual',
#        'exter_cond', 'foundation', 'bsmt_qual', 'bsmt_cond', 'bsmt_exposure',
#        'bsmtfin_type_1', 'bsmtfin_type_2', 'heating', 'heating_qc',
#        'central_air', 'electrical', 'kitchen_qual', 'functional',
#        'fireplace_qu', 'garage_type', 'garage_finish', 'garage_qual',
#        'garage_cond', 'paved_drive', 'pool_qc', 'fence', 'misc_feature',
#        'sale_type'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows = len(object_cols), figsize = (12, 264))

for i, col in enumerate(object_cols):
    object_count = ames_df[col].value_counts(normalize = True).sort_index()
    axes[i].bar(x = ames_df[col].value_counts(normalize = True).sort_index().index,
                height = object_count)
    axes[i].set_xticklabels(ames_df[col].value_counts(normalize = True).sort_index().index, 
                            rotation = 45)
    axes[i].set_title(col, fontweight = 'bold')

#https://stackoverflow.com/questions/43152502/how-can-i-rotate-xticklabels-in-matplotlib-so-that-the-spacing-between-each-xtic
# Out:
# <ipython-input-17-fe146b28ef71>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[i].set_xticklabels(ames_df[col].value_counts(normalize = True).sort_index().index,

# %%
### BREAK ###

#DO PLOTS FOR CONTIOUS VARIABLES

# %%
continuous_col = ames_df.select_dtypes(exclude = 'object').columns
continuous_col
# Out:
# Index(['ms_subclass', 'lot_frontage', 'lot_area', 'overall_qual',
#        'overall_cond', 'year_built', 'year_remod/add', 'mas_vnr_area',
#        'bsmtfin_sf_1', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf',
#        '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area',
#        'bsmt_full_bath', 'bsmt_half_bath', 'full_bath', 'half_bath',
#        'bedroom_abvgr', 'kitchen_abvgr', 'totrms_abvgrd', 'fireplaces',
#        'garage_yr_blt', 'garage_cars', 'garage_area', 'wood_deck_sf',
#        'open_porch_sf', 'enclosed_porch', '3ssn_porch', 'screen_porch',
#        'pool_area', 'misc_val', 'mo_sold', 'yr_sold', 'saleprice'],
#       dtype='object')

# %%
# sns.boxplot(x = ames_df['ms_subclass'])

fig, axes = plt.subplots(nrows = len(continuous_col), figsize = (12, 234))

for i, col in enumerate(continuous_col):
    sns.boxplot(x = ames_df[col], ax = axes [i])
    axes[i].set_title(col, fontweight = 'bold')

# %% [markdown]
# **Scatterplots Related to Sale Price**

# %%
plt.figure(figsize = (12, 8))

plt.title('Overall Quality vs. Sale Price',
          fontsize = 16,
          fontweight = 'bold',
          y = 1.025)

sns.scatterplot(x = ames_df['overall_qual'],
                y = ames_df['saleprice'],
                palette = 'viridis')

plt.xlabel('Overall Quality',
           fontweight = 'bold')

plt.ylabel('Sale Price (in dollars)',
           fontweight = 'bold')

plt.show();

# %%
#checking out the one outlier-looking data point for 'saleprice' where 'overall_qual' == 6
ames_df[(ames_df['overall_qual'] == 6) & (ames_df['saleprice'] > 400_000)]
# Out:
#       ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# 1897           75        RL          60.0     19800   Pave   NaN       Reg
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1897          Lvl    AllPub     Inside        Gtl      Edwards        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1897        Norm      1Fam      2.5Unf             6             8
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1897        1935            1990      Gable   CompShg      BrkFace
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1897      Wd Sdng         None           0.0         TA         TA     BrkTil
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1897        TA        TA            No            Rec         425.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1897            Unf           0.0       1411.0         1836.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1897         Gd           Y      SBrkr        1836        1836
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1897                0         3672             0.0             0.0          3
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1897          1              5              1           Gd              7
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1897        Typ           2           Gd      Detchd         1993.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 1897           Unf          2.0        836.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 1897           Y           684             80              32           0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 1897             0          0     NaN   NaN          NaN         0       12
#
#       yr_sold sale_type  saleprice
# 1897     2006       WD      415000

# %%
plt.figure(figsize = (12, 8))

plt.title('Above Ground Living Area vs. Sale Price',
          fontsize = 16,
          fontweight = 'bold',
          y = 1.025)

sns.scatterplot(x = ames_df['gr_liv_area'],
                y = ames_df['saleprice'],
                palette = 'viridis')

plt.xlabel('Above Ground Living Area, in sqft',
           fontweight = 'bold')

plt.ylabel('Sale Price (in dollars)',
           fontweight = 'bold')

plt.show();

# %% [markdown]
# - Based on the above plot there are two outliers with respect to the relationship between Sale Price and Above Ground Living Area:
#     1) The datapoint around (x = 5,100, y = 190,000)
#     2) The datapoint around (x = 5,700, y = 170,000)

# %%
ames_df[ames_df['gr_liv_area'] > 5000]
# Out:
#       ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# 960            60        RL         313.0     63887   Pave   NaN       IR3
# 1885           20        RL         128.0     39290   Pave   NaN       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 960           Bnk    AllPub     Corner        Gtl      Edwards       Feedr
# 1885          Bnk    AllPub     Inside        Gtl      Edwards        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 960         Norm      1Fam      2Story            10             5
# 1885        Norm      1Fam      1Story            10             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 960         2008            2008        Hip   ClyTile       Stucco
# 1885        2008            2009        Hip   CompShg      CemntBd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 960        Stucco        Stone         796.0         Ex         TA      PConc
# 1885      CmentBd        Stone        1224.0         Ex         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 960         Ex        TA            Gd            GLQ        5644.0
# 1885        Ex        TA            Gd            GLQ        4010.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 960             Unf           0.0        466.0         6110.0    GasA
# 1885            Unf           0.0       1085.0         5095.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 960          Ex           Y      SBrkr        4692         950
# 1885         Ex           Y      SBrkr        5095           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 960                 0         5642             2.0             0.0          2
# 1885                0         5095             1.0             1.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 960           1              3              1           Ex             12
# 1885          1              2              1           Ex             15
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 960         Typ           3           Gd      Attchd         2008.0
# 1885        Typ           2           Gd      Attchd         2008.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 960            Fin          2.0       1418.0          TA          TA
# 1885           Fin          3.0       1154.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 960            Y           214            292               0           0
# 1885           Y           546            484               0           0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 960              0        480      Gd   NaN          NaN         0        1
# 1885             0          0     NaN   NaN         Elev     17000       10
#
#       yr_sold sale_type  saleprice
# 960      2008       New     160000
# 1885     2007       New     183850

# %%
plt.figure(figsize = (12, 8))

plt.title('Garage Area vs. Sale Price, hued by Garage Car Capacity',
          fontsize = 16,
          fontweight = 'bold',
          y = 1.025)

sns.scatterplot(x = ames_df['garage_area'],
                y = ames_df['saleprice'],
                hue = ames_df['garage_cars'],
                palette = 'viridis')

plt.xlabel('Garage Area, in sqft',
           fontweight = 'bold')

plt.ylabel('Sale Price (in dollars)',
           fontweight = 'bold')

plt.show();

# %% [markdown]
# - The above plot shows the relationship between Garage Area and Sale Price, with datapoints hued according to the Garage's car capacity

# %%
plt.figure(figsize = (12, 8))

plt.title('Year Built vs. Sale Price, hued by Overall Quality',
          fontsize = 16,
          fontweight = 'bold',
          y = 1.025)

sns.scatterplot(x = ames_df['year_built'],
                y = ames_df['saleprice'],
                hue = ames_df['overall_qual'],
                palette = 'viridis')

plt.xlabel('Year Built',
           fontweight = 'bold')
plt.ylabel('Sale Price (in dollars)',
           fontweight = 'bold')

plt.legend()
# plt.legend([], [], frameon = False) #to remove the legend

plt.show()

# %%
plt.figure(figsize = (12, 10))

plt.title('Total Rooms above Ground versus Sale Price, by Overall Quality')

sns.scatterplot(x = ames_df['totrms_abvgrd'],
                y = ames_df['saleprice'],
                hue = ames_df['overall_qual'],
                palette = 'viridis')

plt.xlabel('Number of Rooms above Ground')

plt.ylabel('Sale Price (in dollars)')

plt.legend()

plt.show()

# %% [markdown]
# **Additional Visualizations**

# %%
#kde plot for 'lot_area' (all values)
plt.figure(figsize = (8, 6))

plt.title('Frequency of "Lot Area" Measurements',
          fontsize = 16,
          fontweight = 'bold',
          y = 1.025)

sns.kdeplot(x = 'lot_area', shade = 'fill', data = ames_df)

plt.xlabel(xlabel = 'Lot Area, in sqft',
           fontweight = 'bold')
plt.ylabel(ylabel = 'Density',
           fontweight = 'bold')

plt.yticks([]);

# %% [markdown]
# - A plot representing the frequency of 'Lot Area' measurements across houses in the dataset

# %%
ames_df[ames_df['lot_area'] > 70_000]
# Out:
#       ms_subclass ms_zoning  lot_frontage  lot_area street alley lot_shape  \
# 471            50        RL           NaN    159000   Pave   NaN       IR2
# 694            20        RL           NaN    115149   Pave   NaN       IR2
# 1854           20        RL          62.0     70761   Pave   NaN       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 471           Low    AllPub    CulDSac        Sev      ClearCr        Norm
# 694           Low    AllPub    CulDSac        Sev      ClearCr        Norm
# 1854          Low    AllPub     Inside        Mod      ClearCr        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 471         Norm      1Fam      1.5Fin             6             7
# 694         Norm      1Fam      1Story             7             5
# 1854        Norm      1Fam      1Story             7             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 471         1958            2006      Gable   CompShg      Wd Sdng
# 694         1971            2002      Gable   CompShg      Plywood
# 1854        1975            1975      Gable   WdShngl      Plywood
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 471       HdBoard       BrkCmn         472.0         Gd         TA     CBlock
# 694       Plywood        Stone         351.0         TA         TA     CBlock
# 1854      Plywood         None           0.0         TA         TA     CBlock
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 471         Gd        TA            Gd            Rec         697.0
# 694         Gd        TA            Gd            GLQ        1219.0
# 1854        Gd        TA            Gd            ALQ         655.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 471             Unf           0.0        747.0         1444.0    GasA
# 694             Unf           0.0        424.0         1643.0    GasA
# 1854            Unf           0.0        878.0         1533.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 471          Gd           Y      SBrkr        1444         700
# 694          TA           Y      SBrkr        1824           0
# 1854         TA           Y      SBrkr        1533           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 471                 0         2144             0.0             1.0          2
# 694                 0         1824             1.0             0.0          2
# 1854                0         1533             1.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 471           0              4              1           Gd              7
# 694           0              2              1           Gd              5
# 1854          0              2              1           Gd              5
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 471         Typ           2           TA      Attchd         1958.0
# 694         Typ           2           TA      Attchd         1971.0
# 1854        Typ           2           TA      Attchd         1975.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 471            Fin          2.0        389.0          TA          TA
# 694            Unf          2.0        739.0          TA          TA
# 1854           Unf          2.0        576.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 471            Y             0             98               0           0
# 694            Y           380             48               0           0
# 1854           Y           200             54               0           0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 471              0          0     NaN   NaN         Shed       500        6
# 694              0          0     NaN   NaN          NaN         0        6
# 1854             0          0     NaN   NaN          NaN         0       12
#
#       yr_sold sale_type  saleprice
# 471      2007       WD      277000
# 694      2007       WD      302000
# 1854     2006       WD      280000

# %%
#kde plot for 'lot_area' (values less than 70_000)
plt.figure(figsize = (8, 6))

plt.title('Frequency of "Lot Area" Measurements (under 70,000 sqft)',
          fontsize = 16,
          fontweight = 'bold',
          y = 1.025)

sns.kdeplot(x = 'lot_area', shade = 'fill', data = ames_df[ames_df['lot_area'] < 70_000])

plt.xlabel(xlabel = 'Lot Area, in sqft',
           fontweight = 'bold')
plt.ylabel(ylabel = 'Density',
           fontweight = 'bold')

plt.yticks([]);

# %% [markdown]
# - A plot representing the frequency of 'Lot Area' measurements across houses in the dataset, excluding measurements over 70,000 sqft

# %%
#looking at 'condition_x', Proximity to main road or railroad
print(ames_df['condition_1'].value_counts().sort_index())
print('_break_')
print(ames_df['condition_2'].value_counts().sort_index())
# Out:
# Artery      70
# Feedr      109
# Norm      1767
# PosA        12
# PosN        27
# RRAe        21
# RRAn        36
# RRNe         3
# RRNn         6
# Name: condition_1, dtype: int64
# _break_
# Artery       5
# Feedr       11
# Norm      2025
# PosA         3
# PosN         3
# RRAe         1
# RRAn         1
# RRNn         2
# Name: condition_2, dtype: int64

# %%
#function to generate count plots
def make_countplot(dataframe,
                   x = None,
                   hue = None,
                   palette = 'viridis',
                   ax = None):
    
    return sns.countplot(data = dataframe,
                         x = x,
                         hue = hue,
                         palette = palette,
                         ax = ax)

# %%
fig, axes = plt.subplots(nrows = 1,
                         ncols = 2, 
                         sharey = True,
                         sharex = True,
                         figsize = (13, 6))

fig.suptitle('Counts - Proximity to Main Rd or Railroad',
             fontsize = 16,
             fontweight = 'bold')

ax0 = make_countplot(ames_df, 
                     x = 'condition_1',
                     palette = 'viridis',
                     ax = axes[0])
ax0.set(xlabel = 'Proximity to Main Rd or Railroad',
        ylabel = 'Count')

ax1 = make_countplot(ames_df, 
                     x = 'condition_2',
                     palette = 'viridis',
                     ax = axes[1])
ax1.set(xlabel = 'Proximity to Main Rd or Railroad - if Present',
        ylabel = 'Count');

# %% [markdown]
# - Side-by-side plots representing the counts of the categorical variables 'condition_1' and 'condition_2', the proximity of the house to a Main Rd or Railroad, offering a comparison between the two features.

# %%
print(ames_df['overall_qual'].value_counts().sort_index())
print('_break_')
print(ames_df['overall_cond'].value_counts().sort_index())
# Out:
# 1       4
# 2       9
# 3      29
# 4     159
# 5     563
# 6     506
# 7     431
# 8     250
# 9      77
# 10     23
# Name: overall_qual, dtype: int64
# _break_
# 1       4
# 2       6
# 3      35
# 4      70
# 5    1168
# 6     368
# 7     270
# 8     101
# 9      29
# Name: overall_cond, dtype: int64

# %%
fig, axes = plt.subplots(nrows = 1,
                         ncols = 2, 
                         sharey = True,
                         sharex = True,
                         figsize = (13, 6))

fig.suptitle('Counts - Proximity to Main Rd or Railroad',
             fontsize = 16,
             fontweight = 'bold')

ax0 = make_countplot(ames_df, 
                     x = 'overall_qual',
                     palette = 'viridis',
                     ax = axes[0])
ax0.set(xlabel = 'Overall Quality',
        ylabel = 'Count')

ax1 = make_countplot(ames_df, 
                     x = 'overall_cond',
                     palette = 'viridis',
                     ax = axes[1])
ax1.set(xlabel = 'Overall Condition',
        ylabel = 'Count');

# %% [markdown]
# - Side-by-side plots representing the counts of the variables 'overall_qual' and 'overall_cond', the overall material and finish quality and the overall condition rating, respectively.

# %%
plt.figure(figsize = (12, 6))

plt.title('Number of Houses Built in a Year - Ames, Iowa', 
          fontsize = 16, 
          fontweight = 'bold', 
          y = 1.025)

ames_df['year_built'].value_counts().sort_index().plot(linewidth = 1.5,
                                                       color = 'gold')

plt.xticks(fontweight = 'bold')

plt.yticks(fontweight = 'bold');

# %% [markdown]
# - A line plot representing the number of houses built in a given year (whew, look at that 'Housing Bubble' burst)

# %%
plt.figure(figsize = (12, 6))

plt.title('Houses with Remodels or Additions in a Year - Ames, Iowa', 
          fontsize = 16, 
          fontweight = 'bold', 
          y = 1.025)

ames_df['year_remod/add'].value_counts().sort_index().plot(linewidth = 1.5,
                                                           color = 'gold')

plt.xticks(fontweight = 'bold')

plt.yticks(fontweight = 'bold');

# %% [markdown]
# - A line plot representing the number of houses either remodeled or added onto in a given year

# %%
#IN THE PROCESS ON COMPLETING EDA I GENERATED LOTS OF COUNTPLOTS.
#I NEED TO GO THROUGH AND NEATEN THINGS UP WITH THE ABOVE FUNCTION.

#WORDS #WORDS #WORDS 
#WORDS #WORDS #WORDS 
#WORDS #WORDS #WORDS

# %%
print(ames_df['exter_qual'].value_counts().sort_index())
print('_break_')
print(ames_df['exter_cond'].value_counts().sort_index())
# Out:
# Ex      81
# Fa      26
# Gd     697
# TA    1247
# Name: exter_qual, dtype: int64
# _break_
# Ex       7
# Fa      49
# Gd     215
# Po       2
# TA    1778
# Name: exter_cond, dtype: int64

# %%
fig, axes = plt.subplots(nrows = 1,
                         ncols = 2, 
                         sharex = True,
                         sharey = True, 
                         figsize = (13, 6))

fig.suptitle('Counts - Exterior Quality and Condition of Houses',
             fontsize = 16,
             fontweight = 'bold')

sns.countplot(ax = axes[0], x = 'exter_qual', data = ames_df, palette = 'viridis').set(xlabel = 'Exterior Quality', ylabel = 'Count')

sns.countplot(ax = axes[1], x = 'exter_cond', data = ames_df, palette = 'viridis').set(xlabel = 'Exterior Condition', ylabel = 'Count');

# %% [markdown]
# - Side-by-side plots representing the counts of the categorical variables 'exter_qual' and 'exter_cond', the exterior material quality and the present condition of the material on the exterior, respectively.

# %%
print(ames_df['bsmt_qual'].value_counts().sort_index())
print('_break_')
print(ames_df['bsmt_cond'].value_counts().sort_index())
#Consider, should I re-assign these on a scale 1-5
# Out:
# Ex    184
# Fa     60
# Gd    864
# Po      1
# TA    887
# Name: bsmt_qual, dtype: int64
# _break_
# Ex       3
# Fa      65
# Gd      89
# Po       5
# TA    1834
# Name: bsmt_cond, dtype: int64

# %%
fig, axs = plt.subplots(figsize = (13, 6),
                        nrows = 1,
                        ncols = 2,
                        sharex = True,
                        sharey = True)

plt.suptitle('Counts - Basement Quality and Condition of Houses', fontweight = 'bold');

make_countplot(ames_df, x = 'bsmt_qual', palette = 'viridis', ax = axs[0]).set(xlabel = 'Basement Quality',
                                                                               ylabel = 'Count')
make_countplot(ames_df, x = 'bsmt_cond', palette = 'viridis', ax = axs[1]).set(xlabel = 'Basement Condition',
                                                                               ylabel = 'Count');

# %% [markdown]
# - Side-by-side plots representing the counts of the categorical variables 'bsmt_qual' and 'bsmt_cond', the height of the basement and the general condition of the basement, respectively.

# %%
fig, axes = plt.subplots(nrows = 1,
                         ncols = 3, 
                         sharex = True,
                         sharey = True, 
                         figsize = (18, 6))

fig.suptitle('Counts - Exterior Quality and Condition of Houses',
             fontsize = 16,
             fontweight = 'bold')

ax0 = sns.kdeplot(ax = axes[0], x = '1st_flr_sf', shade = 'fill', data = ames_df)
ax0.set(xlabel = '1st Floor SqFt')

ax1 = sns.kdeplot(ax = axes[1], x = '2nd_flr_sf', shade = 'fill', data = ames_df)
ax1.set(xlabel = '2nd Floor SqFt')

ax2 = sns.kdeplot(ax = axes[2], x = 'gr_liv_area', shade = 'fill', data = ames_df)
ax2.set(xlabel = 'Total Above Ground Living Area');

# %% [markdown]
# - Plots showing the density/distributions of square footage for 1st and 2nd floors, as well as total above ground living area.

# %%
print(ames_df['full_bath'].value_counts().sort_index())
print('_break_')
print(ames_df['half_bath'].value_counts().sort_index())
# Out:
# 0       8
# 1     900
# 2    1096
# 3      45
# 4       2
# Name: full_bath, dtype: int64
# _break_
# 0    1308
# 1     725
# 2      18
# Name: half_bath, dtype: int64

# %%
fig, axs = plt.subplots(figsize = (14, 7),
                        nrows = 1,
                        ncols = 2,
                        sharey = True)

plt.suptitle('Counts - Basement Quality and Condition of Houses', fontweight = 'bold');

make_countplot(ames_df, x = 'full_bath', palette = 'viridis', ax = axs[0]).set(xlabel = 'Number of Full Bathrooms',
                                                                               ylabel = 'Count')
make_countplot(ames_df, x = 'half_bath', palette = 'viridis', ax = axs[1]).set(xlabel = 'Number of Half Bathrooms',
                                                                               ylabel = 'Count');

# %% [markdown]
# - Side-by-side plots representing the counts of the variables 'full_bath' and 'half_bath', the number of full and half bathrooms in a house.

# %%
print(ames_df['garage_qual'].value_counts().sort_index())
print('_break_')
print(ames_df['garage_cond'].value_counts().sort_index())
# Out:
# Ex       3
# Fa      82
# Gd      18
# Po       2
# TA    1832
# Name: garage_qual, dtype: int64
# _break_
# Ex       2
# Fa      47
# Gd      12
# Po       8
# TA    1868
# Name: garage_cond, dtype: int64

# %%
fig, axs = plt.subplots(figsize = (16, 8),
                        nrows = 1,
                        ncols = 2,
                        sharex = True,
                        sharey = True)

plt.suptitle('Counts - Garage Quality and Condition of Houses', fontweight = 'bold');

make_countplot(ames_df, x = 'garage_qual', palette = 'viridis', ax = axs[0]).set(xlabel = 'Garage Quality',
                                                                               ylabel = 'Count')
make_countplot(ames_df, x = 'garage_cond', palette = 'viridis', ax = axs[1]).set(xlabel = 'Garage Condition',
                                                                               ylabel = 'Count');

# %% [markdown]
# - Side-by-side plots representing the counts of the categorical variables 'garage_qual' and 'garage_cond', the quality and condition of a house's garage.

# %% [markdown]
# **Additional Data Visualizations - Based on Correlation**

# %%
plt.figure(figsize = (16, 16))

plt.title('Correlation Heatmap',
          fontsize = 16,
          fontweight = 'bold',
          y = 1.025)

sns.heatmap(ames_df.corr(),
#             annot = True,
#             fmt = '.2f',
            linewidth = .1,
            vmin = -1,
            vmax = 1,
            cmap = 'viridis');

# %%
plt.figure(figsize = (8, 12))

plt.title('Correlation Heatmap - In Relation to Sales Price',
          fontsize = 16,
          fontweight = 'bold',
          y = 1.025)

sns.heatmap(ames_df.corr()[['saleprice']].sort_values('saleprice', ascending = False),
            vmin = -1,
            vmax = 1,
            annot = True,
            linewidths = 1,
            cmap='viridis');

# %%
ames_corr = ames_df.corr()['saleprice'][:-1]
ames_corr[(ames_corr > 0.4)].sort_values(ascending = False)
# Out:
# overall_qual      0.800207
# gr_liv_area       0.697038
# garage_area       0.650270
# garage_cars       0.648220
# total_bsmt_sf     0.628925
# 1st_flr_sf        0.618486
# year_built        0.571849
# year_remod/add    0.550370
# garage_yr_blt     0.540931
# full_bath         0.537969
# mas_vnr_area      0.512230
# totrms_abvgrd     0.504014
# fireplaces        0.471093
# bsmtfin_sf_1      0.423519
# Name: saleprice, dtype: float64

# %%
sns.pairplot(ames_df[['overall_qual', 'gr_liv_area', 'garage_area', 'garage_cars',
                      'total_bsmt_sf', '1st_flr_sf', 'year_built', 'year_remod/add',
                      'garage_yr_blt', 'full_bath', 'mas_vnr_area', 'totrms_abvgrd',
                      'fireplaces', 'bsmtfin_sf_1']]);

# %% [markdown]
# **Saving to .csv Files**

# %%
ames_df.to_csv('../datasets/train_clean.csv',
               index = False)

# %%
ames_test_df.to_csv('../datasets/test_clean.csv',
                    index = False)
